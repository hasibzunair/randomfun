# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("dog.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img.shape
# Out:
# (2848, 4272, 3)

# %%
plt.imshow(img)

# %%
px = img[100, 100]
px
# Out:
# array([117, 124, 132], dtype=uint8)

# %%
blue = img[100, 100, 0]
blue
# Out:
# 117

# %%
img[100, 100] = [255, 255, 255]
img[100, 100]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
img.size
# Out:
# 36499968

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
roi = img[500:2000, 1000:3000]
roi.shape
# Out:
# (1500, 2000, 3)

# %%
plt.imshow(roi)

# %%
r, g, b = cv2.split(img)
r.shape, g.shape, b.shape
# Out:
# ((2848, 4272), (2848, 4272), (2848, 4272))

# %%
b = img[:,:,0] # only blue channel
b.shape
# Out:
# (2848, 4272)

# %%
plt.imshow(b)

# %%
img = cv2.imread("dog.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img.shape
# Out:
# (2848, 4272)

# %%
plt.imshow(img, cmap='gray')

# %%
def pad_image_for_square( img ):
    #import pdb; pdb.set_trace()
    (rows, cols, dim) = img.shape
    resize_dim = max( rows, cols)
    pad_row = resize_dim - rows
    pad_col = resize_dim - cols
    print(pad_row)
    print(pad_col)
    img = np.pad(img, ((0,pad_row), (0, pad_col), (0,0)), 'constant', constant_values=0)
    return img

# %%
img = cv2.imread("dog.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img.shape
# Out:
# (2848, 4272, 3)

# %%
#img = cv2.resize(img, (2000, 2000), interpolation=cv2.INTER_CUBIC) # cubic, area, linear
#img.shape

# %%
img_pad = pad_image_for_square(img)
img_pad.shape
# Out:
# 1424
# 0
# (4272, 4272, 3)

# %%
plt.imshow(img_pad)
